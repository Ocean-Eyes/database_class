# %% [markdown]
# <a href="https://colab.research.google.com/github/Ocean-Eyes/database_class/blob/main/MidtermHW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Erwin Data Modeler Image

# %% [markdown]
# ![DB Erwin data modeler image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Insert data into DB that is written by SQL

# %%
from sqlalchemy import create_engine
my_conn = create_engine("sqlite:////content/Midterm_HW_script.sqlite")

# %%
r_set = my_conn.execute('''INSERT INTO 'country'
('name', 'language') VALUES
(1, 'Germany', 'DE'),
(2, 'Spain', 'ES'),
(3, 'Sweden', 'SE');''')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1900                     self.dialect.do_execute(
# -> 1901                         cursor, statement, parameters, context
#    1902                     )
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     735     def do_execute(self, cursor, statement, parameters, context=None):
# --> 736         cursor.execute(statement, parameters)
#     737
#
# OperationalError: no such table: country
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ...

# %% [markdown]
# 3. Show data table that is made by python code.

# %%
r_set = my_conn.execute('''SELECT * from country''')
for row in r_set:
  print(row)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1900                     self.dialect.do_execute(
# -> 1901                         cursor, statement, parameters, context
#    1902                     )
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     735     def do_execute(self, cursor, statement, parameters, context=None):
# --> 736         cursor.execute(statement, parameters)
#     737
#
# OperationalError: no such table: country
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ...
